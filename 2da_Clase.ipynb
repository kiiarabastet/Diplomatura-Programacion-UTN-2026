# %% [markdown]
# <a href="https://colab.research.google.com/github/kiiarabastet/Diplomatura-Programacion-UTN-2026/blob/main/2da_Clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#OPERADORES ARITMÉTICOS

valor1 = 5
valor2 = 3

#SUMA
suma = valor1 + valor2 #Las variables que guardan como resultado Sumas, las llamo SUMADORES!!
print(suma)

#Python es case sensitive !!!
Suma = "hola"
print(Suma)

#PRODRÍAMOS MOSTRARLO MEJOR...
print(valor1, "+", valor2, "=", suma)
#Imprimir por pantalla con Foramto!
print(f"{valor1} + {valor2} = {suma}")
#print(f)


#RESTA
resta = valor1 -valor2
print(resta)
print(f"{valor1} - {valor2} = {resta}")

resta = valor2 - valor1
print(resta)
print(f"{valor2} - {valor1} = {resta}")


#MULTIPLICACIÓN *

multiplicación = valor1 * valor2
print(f"{valor1} * {valor2} = {multiplicación}")


#DIVISIÓN /

division = valor1 / valor2
print(f"{valor1} / {valor2} = {division}")

division = valor2 / valor1
print(f"{valor2} / {valor1} = {division}")

#DIVISIÓN ENTERA //
division = valor1 // valor2
print(f"DIVISIÓN ENTERA{valor1} / {valor2} = {division}")


#MÓDULO (resto de dividir valor1 y valor2)
resultado= valor1 % valor2
print(f"{valor2} % {valor1} = {modulo}")

valor1 = 17
valor2 = 6
resultado = valor1 % valor2
print(f"RESTO de dividir {valor1} % {valor2} = {resultado}")


#POTENCIA **

valor1 = 3
valor1 = 2
potencia = valor1 ** valor2

print(potencia)
# Out:
# 8
# hola
# 5 + 3 = 8
# 5 + 3 = 8
# 2
# 5 - 3 = 2
# -2
# 3 - 5 = -2
# 5 * 3 = 15
# 5 / 3 = 1.6666666666666667
# 3 / 5 = 0.6
# DIVISIÓN ENTERA5 / 3 = 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3062/4254712366.py in <cell line: 0>()
#      50 #MÓDULO (resto de dividir valor1 y valor2)
#      51 resultado= valor1 % valor2
# ---> 52 print(f"{valor2} % {valor1} = {modulo}")
#      53
#      54 valor1 = 17
#
# NameError: name 'modulo' is not defined
