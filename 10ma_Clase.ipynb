# %% [markdown]
# <a href="https://colab.research.google.com/github/kiiarabastet/Diplomatura-Programacion-UTN-2026/blob/main/10ma_Clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Defino mi primera lista:

Lista = ["1/2 kg d epan", 1, 2, 3, True, "Python",1]
print(dir(Lista))
print(f"****{Lista}****")
print(f"La longitud de mi lista es: {len(Lista)}") # len le da longitud

# %%
Lista.a´´ed(int(input("ingrese elemento a agregar a la lista: ")))

# %%
Nombres = ["Kiara", "Juan", "Daniel", "Ariel", "Josefina", "Marisa"]
nombre= input("")

# %%
print(Nombres)


nombre = input("Ingrese el vlaor a verificar: ")

if nombre in Nombres: #(Si nombre está en nombre)
  for i in range(len(Nombres)):
    print(Nombres[i])   #recorro por ele índice de la lista, no por elemento
    if nombre == Nombres[i]:
      indice=i
      #print(f"Es igual !!! {nombre} == {Nombres[i]}")
    #else:
      #print(f"Es distinto!!! {nombre} != {Nombres[i]}")
    #input("Presione una tecla para continuar")

  print(f"El lemento {nombre} se encuentra en la posición {indice}")
else:
  print("el nombre no está")

print("Mismo ejercicio, pero mas simple y más corto...")
print(f"El elemento {nombre} se encuentra en la posición {Nombres.index(nombre)}")

# %%
#pop borra por posición!
Lista.pop(4)
print(Lista)

# %%
#convertir nombre a mayúscula
print("Lista original")
print(Nombres)
print(f"nombre pasado a mayuscula {nombre.upper()}")   # ()aqui van los parámetros de las funciones etc etc no entra en el examen para qué se usan
print(f"nombre pasado a minuscula {nombre.lower()}")

print("\n Lista completa en mayuscula en un solo paso")
Nombres Mayúscula [elemento.upper() for elemento in Nombres]
print(Nombres_Mayúscula)


print("\n Lista completa en mayúscula paso a paso")
Nombres Mayúscula =[] #los corchetes vacíos sisgnifica que es una lista vacía
for elemnto in Nombres:
  #print(elemento)
  Nombres_Mayúscula.apped(elemento.upper())
  #print(Nombres_Mayúscula)
  #input("Presione cualquier tecla para continuar")

print("\n Lista completa en Mayuscula")
print(Nombres_Mayúscula)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1685/3776764327.py in <cell line: 0>()
#       1 #convertir nombre a mayúscula
#       2
# ----> 3 print(nombre.upper())
#       4 print(nombre.lower)
#
# NameError: name 'nombre' is not defined
