# %% [markdown]
# <a href="https://colab.research.google.com/github/kiiarabastet/Diplomatura-Programacion-UTN-2026/blob/main/3ra_Clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#valor1 = 5
#valor2 = 3

valor1 = int(input("Ingrese el primer valor a sumar "))
valor2 = int(input("Ingrese el segundo valor a sumar "))

suma = valor1 + valor2

print(f"suma")

print(f"{valor1} + {valor2} = {suma}")

resta = valor1 - valor2

print(f"resta")

print(f"{valor1} - {valor2} = {resta}")


#NQV Para comprobar que funciona sacar # de comentario
#valor3 = int(input("Holu"))
#print(valor3)
# Out:
# Ingrese el primer valor a sumar 7
# Ingrese el segundo valor a sumar 3
# suma
# 7 + 3 = 10
# resta
# 7 - 3 = 4

# %%
#TIPOS BÁSICOS Y OPERACIONES DE CADENA DE CARACTERES

parte1 = input("Ingrese parte 1: ")
parte2 = input("Ingrese parte 2: ")

suma = parte1 + " " + parte2 #SUMA DE DOS CADENAS DE CARACTERES:   CONCATENAR (pegar los textos)
print(suma)

mi_cadena_multilinea = """
Esta es una cadena
de varias lìneas,
no de una sola
"""
print(mi_cadena_multilinea)
# Out:
# Ingrese parte 1: 5
# Ingrese parte 2: 3
# 5 3
#
# Esta es una cadena
# de varias lìneas,
# no de una sola

# %%
#Leer nombre y apellido de la persona, su edad, DNI y luegho mostrar en pantalla: APELLIDO, NOMBRE tiene xx años y su DNI es 11.111.11


Nombre = input("Ingrese nombre: ")
Apellido = input("Ingrese apellido: ")
Edad = int(input("Ingrese su edad: "))
DNI = input("Ingrese su DNI: ")

print(f"{Apellido}, {Nombre} tiene {Edad} años y su DNI es {DNI}")

#2- Leer por teclado el nombre de 4 jugadores y un puntaje para cada uno. El programa mostrará
# Out:
# Ingrese nombre: Kiara
# Ingrese apellido: Ojeda
# Ingrese su edad: 24
# Ingrese su DNI: 43.801.176
# Ojeda, Kiara tiene 24 años y su DNI es 43.801.176
